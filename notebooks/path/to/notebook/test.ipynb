// %% [markdown]
// # test
//
// This is a text cell. Start editing!

// %%
val y = 1
print(y)
// Out:
// 1

// %%
spark.sparkContext
// Out:
// org.apache.spark.SparkContext@56facf73

// %%
spark.version
// Out:
// 3.5.8
